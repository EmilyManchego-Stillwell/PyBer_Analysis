# %%
# %matplotlib inline

# %%
#Import dependencies
import matplotlib.pyplot as plt

# %%
#Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

#Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis, y_axis)
#plt.xlabel("Month")
#plt.ylabel("Total Fare (US Dollars)")
#plt.title("Ride Sharing")
#plt.show()

# %%
#Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
#Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
#Create the plot with the ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
#Create the plot and add a label for the legend
plt.plot(x_axis, y_axis, label = "Boston")

#Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")

#Set the y limit between 0 and 45.
plt.ylim(0,45)

#Create a title
plt.title("PyBer Fare by Month")

#Add the legend.
plt.legend()

# %%
#Create the plot
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label="Boston")

#Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")

#Set the y limit between 0 and 45.
plt.ylim(0,45)

#Create a title
plt.title("PyBer Fare by Month")

#Add a grid
plt.grid()

#Add the legend.
plt.legend()

# %%
#Create the plot
plt.plot(x_axis, y_axis, marker="D", color="green", linewidth=2, label="Boston")

#Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")

#Set the y limit between 0 and 45.
plt.ylim(0,45)

#Create a title
plt.title("PyBer Fare by Month")

#Add a grid
plt.grid()

#Add the legend.
plt.legend()

# %% [markdown]
# ## Bar Charts using MATLAB Approach

# %%
#Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#Create the plot
plt.bar(x_axis, y_axis, color="green", label="Boston")

#Set y limit between 0 & 45
plt.ylim(0,45)

#Create labels for the x and y axes
plt.xlabel("Date")
plt.ylabel("Fare ($)")

#Create a title.
plt.title("PyBer Fare by Month")

#Add the legend
plt.legend()

# %% [markdown]
# ### Create Horizontal Bar Chart

# %%
#Create the plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#Putting data on oppposite axes
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#Create the plot with axes in correct spot and make y-axis in ascending order
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
#Skill Drill 5.1.5
plt.barh(x_axis, y_axis, color="Magenta", label="Boston")
plt.xlabel("Fare ($)")
plt.ylabel("Date")
plt.title("PyBer Fare by Month")
plt.gca().invert_yaxis()
plt.legend()

# %% [markdown]
# # Create Bar Charts Using Object-Oriented Approach

# %%
#Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# ### Create Horizontal Bar Chart Object Oriented Approach

# %%
#Create the plot with the ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#If you want to change axes in the horizontal bar chart
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#Skill drill 5.6.1
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color="Cyan", label="Chicago")
plt.xlabel("Fare ($)")
plt.ylabel("Date")
plt.title("PyBer Fare by Month")
plt.legend()
plt.gca().invert_yaxis()

# %% [markdown]
# # Create Scatter Plot Using MATLAB Method

# %%
plt.plot(x_axis, y_axis, "o")

# %%
plt.scatter(x_axis, y_axis)

# %%
#Skill Drill 5.7.1
plt.scatter(y_axis, x_axis, c="Red", label="Chicago")
plt.xlim(0,50)
plt.xlabel("Month")
plt.ylabel("Fare ($)")
plt.title("PyBer Fare by Month")
plt.gca().invert_yaxis()
plt.legend()

# %% [markdown]
# ## Create Bubble Chart using MATLAB Method

# %%
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
plt.scatter(x_axis, y_axis, s = [i*3 for i in y_axis])

# %% [markdown]
# ### Create a Scatter Plot Using Object-Oriented Interface

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %% [markdown]
# #### Create a Bubble Chart using Obj-Oriented Interface

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %%
#Skill Drill 5.1.7(2)

fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis, c="xkcd:sky blue", s=[i*5 for i in y_axis], alpha=0.8, edgecolors="black", linewidth=2, label="Boston")
plt.xlim(0,50)
plt.xlabel("Fare ($)")
plt.ylabel("Date")
plt.title("PyBer Fare by Month")
plt.gca().invert_yaxis()
plt.legend()

# %% [markdown]
# # Creating Pie Charts

# %% [markdown]
# ### Using MATLAB Method

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
#Assign 12 colors, one for each month
colors = ["slateblue","magenta","lightblue","green","yellowgreen","greenyellow","yellow","orange","gold","indianred","tomato","mistyrose"]
explode_values = (0,0,0,0,0,0,0.2,0,0,0,0,0)
plt.subplots(figsize=(8,8))
plt.pie(y_axis,
        explode=explode_values, 
        colors=colors,
        labels=x_axis, 
        autopct="%.1f%%")
plt.show()

# %% [markdown]
# ### Using Obj-Oriented Interface

# %%
fig, ax = plt.subplots()
ax.pie(y_axis, labels=x_axis)
plt.show()

# %%
#Skill Drill 5.1.8
fig, ax = plt.subplots(figsize=(8,8))
colors = ["purple", "cyan", "seagreen", "skyblue", "greenyellow", "magenta", "blue", "#d29bf2", "gold", "lightgreen", "#f29bb2", "green"]
explode_values = (0,0,0.2,0,0,0,0.2,0,0,0,0,0)
ax.pie(y_axis,
       explode=explode_values,
       colors=colors,
       labels=x_axis,
       shadow=True,
       startangle=95,
       rotatelabels=False,
       counterclock=False,
       autopct="%.1f%%")
plt.show()
